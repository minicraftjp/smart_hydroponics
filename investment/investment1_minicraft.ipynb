# %% [markdown]
# <a href="https://colab.research.google.com/github/minicraftjp/studywithme/blob/main/investment/investment1_minicraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Candle Stick Example

# %% [markdown]
# ## Only install these for the first time
# ## 最初にこのPythonのパッケージをインストールしてください

# %%
# !pip install pandas_datareader
# !pip install datetime
# !pip install mplfinance

# %% [markdown]
# ## Install Python Packages

# %%
import pandas_datareader as pdr
import datetime as dt
import mplfinance as mpf

# %% [markdown]
# ## Get Stock Information from Yahoo Finance

# %%
df = pdr.get_data_yahoo("AAPL", dt.datetime(2020,4,21), dt.datetime.now())

# %% [markdown]
# ## Plot Stock

# %%
mpf.plot(df, type='candle',
            title='Apple Candlestick',
            ylabel='Price',
            ylabel_lower='Volume',
            volume=True,
            mav=(1,15,30))
